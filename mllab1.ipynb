# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/data.csv')
display(data)
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.head() #displays the first 5 rows
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.tail() #displays the last 5 rows
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
df.shape #returns the number of rows and columns
# Out:
# (11914, 16)

# %%
df.size #returns the total data
# Out:
# 190624

# %%
df.columns #displays the attribute names
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.dtypes #returns the datatype of each columns
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.describe() #returns various statistical data on the given dataset
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.isnull() #returns the dataset with True if the value is Null, else False
# Out:
#         Make  Model   Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0      False  False  False             False      False             False
# 1      False  False  False             False      False             False
# 2      False  False  False             False      False             False
# 3      False  False  False             False      False             False
# 4      False  False  False             False      False             False
# ...      ...    ...    ...               ...        ...               ...
# 11909  False  False  False             False      False             False
# 11910  False  False  False             False      False             False
# 11911  False  False  False             False      False             False
# 11912  False  False  False             False      False             False
# 11913  False  False  False             False      False             False
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# ...

# %%
df.isnull().sum()#returns the total null values
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine HP']
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64

# %%
df['Engine HP'].isnull().sum()
# Out:
# 69

# %%
df['Engine HP'].fillna(df['Engine HP'].mean(), inplace=True)

# %%
df['Engine HP'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP               0
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.head(50)
# Out:
#              Make       Model  Year                Engine Fuel Type  \
# 0             BMW  1 Series M  2011     premium unleaded (required)
# 1             BMW    1 Series  2011     premium unleaded (required)
# 2             BMW    1 Series  2011     premium unleaded (required)
# 3             BMW    1 Series  2011     premium unleaded (required)
# 4             BMW    1 Series  2011     premium unleaded (required)
# 5             BMW    1 Series  2012     premium unleaded (required)
# 6             BMW    1 Series  2012     premium unleaded (required)
# 7             BMW    1 Series  2012     premium unleaded (required)
# 8             BMW    1 Series  2012     premium unleaded (required)
# 9             BMW    1 Series  2013     premium unleaded (required)
# 10            BMW    1 Series  2013     premium unleaded (required)
# 11            BMW    1 Series  2013     premium unleaded (required)
# 12            BMW    1 Series  2013     premium unleaded (required)
# ...

# %%
df['Driven_Wheels']
# Out:
# 0         rear wheel drive
# 1         rear wheel drive
# 2         rear wheel drive
# 3         rear wheel drive
# 4         rear wheel drive
#                ...
# 11909      all wheel drive
# 11910      all wheel drive
# 11911      all wheel drive
# 11912      all wheel drive
# 11913    front wheel drive
# Name: Driven_Wheels, Length: 11914, dtype: object

# %%
one_hot_encoded_data = pd.get_dummies(df, columns = ['Driven_Wheels'])
display(one_hot_encoded_data)
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
all_wheels=one_hot_encoded_data["Driven_Wheels_all wheel drive"].sum()
four_wheels=one_hot_encoded_data["Driven_Wheels_four wheel drive"].sum()
front_wheels=one_hot_encoded_data["Driven_Wheels_front wheel drive"].sum()
rear_wheels=one_hot_encoded_data["Driven_Wheels_rear wheel drive"].sum()
print(all_wheels,four_wheels,front_wheels,rear_wheels)
# Out:
# 2353 1403 4787 3371

# %%
plt.bar(one_hot_encoded_data['Popularity'],one_hot_encoded_data['Driven_Wheels_front wheel drive'],color ='maroon',
        width = 0.4)
plt.show()

# %%
df.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11914.000000      11884.000000     11908.000000
# mean    2010.384338    249.386070          5.628829         3.436093
# std        7.579740    108.875192          1.780559         0.881315
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    170.000000          4.000000         2.000000
# 50%     2015.000000    227.000000          6.000000         4.000000
# 75%     2016.000000    300.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Year'],color='green',edgecolor='white',bins=12)
# Out:
# (array([ 452.,  372.,  266.,  329.,  406.,  443.,  448.,  550., 1026.,
#          672.,  955., 5995.]),
#  array([1990.  , 1992.25, 1994.5 , 1996.75, 1999.  , 2001.25, 2003.5 ,
#         2005.75, 2008.  , 2010.25, 2012.5 , 2014.75, 2017.  ]),
#  <BarContainer object of 12 artists>)

# %%
plt.hist(df['Engine HP'],color='green',edgecolor='white')
# Out:
# (array([1.695e+03, 4.834e+03, 3.558e+03, 1.057e+03, 4.070e+02, 2.660e+02,
#         8.500e+01, 9.000e+00, 0.000e+00, 3.000e+00]),
#  array([  55. ,  149.6,  244.2,  338.8,  433.4,  528. ,  622.6,  717.2,
#          811.8,  906.4, 1001. ]),
#  <BarContainer object of 10 artists>)

# %%
df.hist()
plt.show()

# %%
corel=df[["Engine HP","Popularity","city mpg"]].corr()
display(corel)
# Out:
#             Engine HP  Popularity  city mpg
# Engine HP    1.000000    0.037315 -0.346308
# Popularity   0.037315    1.000000 -0.003217
# city mpg    -0.346308   -0.003217  1.000000

# %%
import seaborn as sns
sns.heatmap(corel,vmax=.6 ,annot=True,square=True)
plt.show()

# %%
sns.set(style="darkgrid")
sns.regplot(x=df['Engine Cylinders'],y=df['Engine HP'])
plt.show()
